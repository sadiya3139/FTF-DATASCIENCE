# %% [markdown]
# # Day 3 - Operators

# %% [markdown]
# # 1. Declearation of variable

# %%
age = 25
height = 1.70
complex_num = 2 + 3j

# %% [markdown]
# # 2. Area of Triangle

# %%
base = float(input("Enter base: "))
height = float(input("Enter height: "))
area = 0.5 * base * height
print("Area:", area)
# Out:
# Area: 2080.0

# %% [markdown]
# # 3. Perimeter of triangle

# %%
a = float(input("Enter side a: "))
b = float(input("Enter side b: "))
c = float(input("Enter side c: "))
perimeter = a + b + c
print("The perimeter of the triangle is", perimeter)
# Out:
# The perimeter of the triangle is 98.0

# %% [markdown]
# # 4. Rectangle Area & Perimeter

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))
print("Area:", length * width)
print("Perimeter:", 2 * (length + width))
# Out:
# Area: 3575.0
# Perimeter: 240.0

# %% [markdown]
# # 5. Circle

# %%
radius = float(input("Enter radius: "))
pi = 3.14
print("Area:", pi * radius ** 2)
print("Circumference:", 2 * pi * radius)
# Out:
# Area: 6358.5
# Circumference: 282.6

# %% [markdown]
# # 6. Slope, x-intercept, y-intercept of y = 2x - 2

# %%
m = 2
y_intercept = -2
x_intercept = 1  # when y = 0 → 0 = 2x - 2 → x = 1
print("Slope:", m)
print("X-intercept:", x_intercept)
print("Y-intercept:", y_intercept)
# Out:
# Slope: 2
# X-intercept: 1
# Y-intercept: -2

# %% [markdown]
# # 7. Slope

# %%
x1, y1 = 2, 2
x2, y2 = 6, 10
slope = (y2 - y1) / (x2 - x1)
print("Slope:", slope)
# Out:
# Slope: 2.0

# %% [markdown]
# # 8. Compare slopes

# %%
print("Slopes are equal:", m == slope)
# Out:
# Slopes are equal: True

# %% [markdown]
# # 9. Solve y = x^2 + 6x + 9

# %%
import math
a, b, c = 1, 6, 9
discriminant = b**2 - 4*a*c
x = -b / (2*a)
print("Value of x when y = 0:", x)
# Out:
# Value of x when y = 0: -3.0

# %% [markdown]
# # 10. Length comparison

# %%
len_python = len("python")
len_dragon = len("dragon")
print("Length equal:", len_python == len_dragon)
# Out:
# Length equal: True

# %% [markdown]
# # 11. Check 'on' in both

# %%
print('on' in 'python' and 'on' in 'dragon')
# Out:
# True

# %% [markdown]
# # 12. Check jargon

# %%
sentence = "I hope this course is not full of jargon"
print('jargon' in sentence)
# Out:
# True

# %% [markdown]
# # 13. Check 'on' not in both

# %%
print('on' not in 'dragon' and 'on' not in 'python')
# Out:
# False

# %% [markdown]
# # 14. Convert length

# %%
length = len("python")
print(float(length))
print(str(length))
# Out:
# 6.0
# 6

# %% [markdown]
# # 15. Even number check

# %%
num = int(input("Enter a number: "))
print("Even?" , num % 2 == 0)
# Out:
# Even? True

# %% [markdown]
# # 16. Floor division check

# %% [markdown]
# print(7 // 3 == int(2.7))

# %% [markdown]
# # 17. Type comparison

# %%
print(type('10') == type(10))
# Out:
# False

# %% [markdown]
# # 18. Invalid conversion check

# %%
try:
    print(int('9.8') == 10)
except:
    print("Cannot convert '9.8' to int directly")
# Out:
# Cannot convert '9.8' to int directly

# %% [markdown]
# # 19. Weekly earning

# %%
hours = float(input("Enter hours: "))
rate = float(input("Enter rate per hour: "))
pay = hours * rate
print("Your weekly earning is", pay)
# Out:
# Your weekly earning is 18.8

# %% [markdown]
# # 20. Seconds lived

# %%
years = int(input("Enter number of years you have lived: "))
seconds = years * 365 * 24 * 60 * 60
print("You have lived for", seconds, "seconds.")
# Out:
# You have lived for 189216000 seconds.

# %% [markdown]
# # 21. Table

# %%
print("\nTable:")
for i in range(1, 6):
    print(i, 1, i, i*2, i*3)
# Out:
# Table:
# 1 1 1 2 3
# 2 1 2 4 6
# 3 1 3 6 9
# 4 1 4 8 12
# 5 1 5 10 15
