# %% [markdown]
# # Day 5 - Lists

# %% [markdown]
# # Level 1

# %%
empty_list = []
fruits = ["banana", "orange", "mango", "lemon"]

print(len(fruits))
print(fruits[0], fruits[-1])
# Out:
# 4
# banana lemon

# %% [markdown]
# # Modify list

# %%
fruits[0] = "apple"
print(fruits)
# Out:
# ['apple', 'orange', 'mango', 'lemon']

# %% [markdown]
# # Add items

# %%
fruits.append("grape")
print(fruits)
# Out:
# ['apple', 'orange', 'mango', 'lemon', 'grape']

# %% [markdown]
# # Insert

# %%
fruits.insert(2, "pineapple")
print(fruits)
# Out:
# ['apple', 'orange', 'pineapple', 'mango', 'lemon', 'grape']

# %% [markdown]
# # Remove

# %%
fruits.remove("orange")
print(fruits)
# Out:
# ['apple', 'pineapple', 'mango', 'lemon', 'grape']

# %% [markdown]
# # Sort

# %%
fruits.sort()
print(fruits)
# Out:
# ['apple', 'grape', 'lemon', 'mango', 'pineapple']

# %% [markdown]
# # Reverse

# %%
fruits.reverse()
print(fruits)
# Out:
# ['pineapple', 'mango', 'lemon', 'grape', 'apple']

# %% [markdown]
# # Copy

# %%
new_list = fruits.copy()
print(new_list)
# Out:
# ['pineapple', 'mango', 'lemon', 'grape', 'apple']
