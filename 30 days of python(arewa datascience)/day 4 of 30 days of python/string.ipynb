# %% [markdown]
# ## Day 4

# %%
text = "Thirty Days Of Python"

print(len(text))
print(text.upper())
print(text.lower())
print(text.capitalize())
print(text.title())
print(text.swapcase())

print(text[0:6])
print(text.find("Python"))
print(text.replace("Python", "Coding"))

print("Python" in text)
print(text.split())
# Out:
# 21
# THIRTY DAYS OF PYTHON
# thirty days of python
# Thirty days of python
# Thirty Days Of Python
# tHIRTY dAYS oF pYTHON
# Thirty
# 15
# Thirty Days Of Coding
# True
# ['Thirty', 'Days', 'Of', 'Python']

# %% [markdown]
# # Joining

# %%
list_words = ["30", "Days", "Of", "Python"]
print(" ".join(list_words))
# Out:
# 30 Days Of Python
