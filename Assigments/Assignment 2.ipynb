# %% [markdown]
# ### exercise
# A client has been testing a [small form](index.html) to gather some basic data about their client-base. They have brought their findings to you to validate the data they have gathered. You can open the `index.html` page in a browser to take a look at the form.
#
# You have been provided a [dataset of csv records](../../data/form.csv) that contain entries from the form as well as some basic visualizations.The client pointed out that some of the visualizations look incorrect but they're unsure about how to resolve them. You can explore it in the [assignment notebook](assignment.ipynb).

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import pandas as pd
print(pd.__version__)
honey_df=pd.read_csv(r"C:\Users\USER\Downloads\ArewaDS-Machine-Learning-main\ArewaDS-Machine-Learning-main\data\honey.csv")
print(honey_df.head())
# Out:
# 3.0.3
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %% [markdown]
# #### print last 5 rows

# %%
honey_df.tail()
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %% [markdown]
# ### Shape (Row,Colums)

# %%
honey_df.shape
# Out:
# (626, 8)

# %% [markdown]
# ### print columns names

# %%
honey_df.columns
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='str')

# %% [markdown]
# ### print dataset information

# %%
honey_df.info
# Out:
# <bound method DataFrame.info of     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# ...

# %% [markdown]
# ### check missing value

# %%
honey_df.isnull().sum
# Out:
# <bound method DataFrame.sum of      state  numcol  yieldpercol  totalprod  stocks  priceperlb  prodvalue  \
# 0    False   False        False      False   False       False      False
# 1    False   False        False      False   False       False      False
# 2    False   False        False      False   False       False      False
# 3    False   False        False      False   False       False      False
# 4    False   False        False      False   False       False      False
# ..     ...     ...          ...        ...     ...         ...        ...
# 621  False   False        False      False   False       False      False
# 622  False   False        False      False   False       False      False
# 623  False   False        False      False   False       False      False
# 624  False   False        False      False   False       False      False
# 625  False   False        False      False   False       False      False
#
#       year
# 0    False
# 1    False
# 2    False
# ...

# %% [markdown]
# ### statistic summary

# %%
honey_df.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %%
honey_df['state'].value_counts().plot(kind='bar');
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 honey_df['state'].value_counts().plot(kind='bar');
#       2 plt.show()
#
# NameError: name 'honey_df' is not defined

# %%
honey_df['stocks'].value_counts().plot(kind='bar');
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 honey_df['stocks'].value_counts().plot(kind='bar');
#       2 plt.show()
#
# NameError: name 'honey_df' is not defined

# %% [markdown]
# ### Excersices

# %% [markdown]
# ### What happen if you add np.nan and none together

# %%
import numpy as np
print(np.nan + np.nan)
print (np.nan +5)

try:
    print(np.nan + None)
except Exception as e:
    print (e)
# Out:
# nan
# nan
# unsupported operand type(s) for +: 'float' and 'NoneType'

# %% [markdown]
# ## np.nan + None produce a typeError,while operation involving only np.nan generate return nan

# %%
example2 = np.array([2, np.nan, 6, 8]) 
example2.sum(), example2.min(), example2.max()
# Out:
# (np.float64(nan), np.float64(nan), np.float64(nan))

# %%
### Now set an element of int_series equal to None.
### How does that element show up in the Series?
### What is the dtype of the Series?

# %%
example2[2] =None
print(example2)
# Out:
# [ 2. nan nan  8.]

# %%
print(example2.dtype)
# Out:
# float64

# %% [markdown]
# ### # Try running example3[example3.notnull()].
